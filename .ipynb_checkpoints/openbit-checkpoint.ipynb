# %%
# -*- coding:utf-8 -*-
import poloniex
import time
import json

# poloniex API
polo = poloniex.Poloniex()
# 2017/12/12 AM 12:00 @JP
unix_time = 1514646000

#4h間隔で過去180日分 UNIX時間で取得 
chart_data_btc = polo.returnChartData('USDT_BTC', period=14400, start=unix_time-polo.DAY*180, end=unix_time)
chart_data_eth = polo.returnChartData('USDT_ETH', period=14400, start=unix_time-polo.DAY*180, end=unix_time)

# %%
import pandas as pd

# DataFrameに変換
df_btc = pd.DataFrame(chart_data_btc)
df_btc.tail(10)
# Out:
#                close        date            high             low  \
# 1070  14826.99999993  1514505600           14949  14007.62220544
# 1071  14546.27985515  1514520000           15100           14425
# 1072  14280.99999996  1514534400  14698.34440429  13770.00000005
# 1073  14484.21101931  1514548800  14526.80029789  13852.87411951
# 1074  14649.99999989  1514563200  14800.00000003   14260.0000002
# 1075  14305.53422499  1514577600           14656       13976.237
# 1076  13346.55602013  1514592000  14365.38790685           12950
# 1077  13430.18895654  1514606400  13548.95520108           12800
# 1078  13154.86175661  1514620800  13548.50160852           12800
# 1079  12280.00000011  1514635200  13183.34433578           11855
#
#                 open    quoteVolume           volume weightedAverage
# 1070   14307.3458536   905.12758805  13157164.279351  14536.25373158
# 1071  14802.00000021   803.04225976  11869415.938945  14780.56203728
# 1072    14517.999999  1348.58732123  19155752.878701  14204.31037511
# 1073  14280.99999991  1486.47948382  21114091.286464  14204.09196109
# 1074  14441.98275242  1110.23894657  16134655.007307  14532.59684066
# 1075  14611.99035903  1313.25443857  18782650.869227  14302.36998831
# 1076  14305.53422499  3348.03444495  45316478.670153  13535.24864073
# 1077  13343.41005586    1534.326203  20306275.245515  13234.65323463
# 1078  13430.18895654  1634.46269265  21517512.342814  13164.88436204
# 1079  13154.86175664  2892.64766233  35635447.095756  12319.31823561

# %%
df_eth = pd.DataFrame(chart_data_eth)
df_eth.tail(10)
# Out:
#              close        date          high           low          open  \
# 1070  737.11699917  1514505600           738  704.88000172           710
# 1071  728.20614002  1514520000           748  722.42452529  737.11699917
# 1072           722  1514534400   740.0809157           701        730.49
# 1073    744.279301  1514548800    744.279301           710  725.98435996
# 1074  746.02000009  1514563200  754.11111111  728.76579694  742.99999998
# 1075  731.73892108  1514577600  750.29837957           715        746.05
# 1076  681.91725872  1514592000  736.98905466   668.8389372  731.73892101
# 1077  697.09992989  1514606400  699.77046695  658.99999828           679
# 1078  698.99999998  1514620800           700  680.22722357  697.09992982
# 1079   662.9999997  1514635200           699  641.18991755  698.99999997
#
#          quoteVolume           volume weightedAverage
# 1070   2965.93650419  2147485.3756792    724.04967963
# 1071   2981.35168385  2195050.2421961    736.26008433
# 1072   4398.72135398  3164912.9517763    719.50748799
# 1073    4417.0275604  3216808.2054937    728.27442471
# 1074   5771.82837759  4269082.9539158    739.64135359
# 1075    4369.5441841  3193668.6552774    730.89286221
# 1076  12560.45278872  8726675.8190696    694.77398353
# 1077   8674.04674092  5887322.3666217    678.72845771
# 1078   6226.67586781  4315079.9753411    692.99897199
# 1079  10787.63123767  7171234.0144884    664.76447484

# %%
# 短期線：窓幅1日
data_s_btc = df_btc['close'].rolling(window=6).mean() 
data_s_eth = df_eth['close'].rolling(window=6).mean() 
# 長期線：窓幅5日
data_l_btc = df_btc['close'].rolling(window=6*5).mean()
data_l_eth = df_eth['close'].rolling(window=6*5).mean()

# %%
import matplotlib.pyplot as plt
# 描画を綺麗に表示する
from matplotlib.pylab import rcParams
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

rcParams['figure.figsize'] = 15, 6

# 短期線と長期線もプロット
plt.plot(df_btc['close'], color='#7f8c8d')
plt.plot(data_s_btc, color='#f1c40f')  # 短期線
plt.plot(data_l_btc, color='#2980b9')  # 長期線
plt.show()

# %%
# 短期線と長期線もプロット
plt.plot(df_eth['close'], color='#7f8c8d')
plt.plot(data_s_eth, color='#f1c40f')  # 短期線
plt.plot(data_l_eth, color='#2980b9')  # 長期線
plt.show()

# %% [markdown]
# - もとの価格だと学習が進まなかったため、最小、最大値で正規化
# * TODO  fit_transformがよく分かってない

# %%
import numpy as np

# 正規化
data_btc = pd.DataFrame([float(i.get('close')) for i in chart_data_btc])
data_eth = pd.DataFrame([float(i.get('close')) for i in chart_data_eth])

# %% [markdown]
# - 対数化
#     - 人間の感覚に合わせる

# %%
data_btc = np.array(data_btc.astype(np.float32))
data_btc = np.log(data_btc)

# %%
#前日との差
diff_btc = data_btc[1:] - data_btc[:-1]
diff_btc *= 100
sns.distplot(diff_btc)
plt.show()

# %%
# onehotラベル生成　
_t_btc = np.empty((len(data_btc),4),dtype=np.float64)
thresh = np.log(1.01) * 100
print(thresh)
for i in range(1,len(data_btc)):
    # めっちゃ上がる
    if diff_btc[i-1] >= thresh:  
        _t_btc[i] = np.array([1,0,0,0])
    # 上がる
    elif diff >= 0 and diff < thresh: 
        _t_btc[i] = np.array([0,1,0,0])
    # 下がる
    elif diff >= -thresh and  diff < 0: 
        _t_btc[i] = np.array([0,0,1,0])
    # めっちゃ下がる
    else : 
        _t_btc[i] = np.array([0,0,0,1])
# Out:
# 0.995033085317

# %%
# データを入力変数xと出力変数tに切り分け
x_btc, t_btc= [], []

N = len(data_btc)
M = 30 # 入力変数の数：直近30サンプルを使用
for n in range(M, N):
 # 入力変数と出力変数の切り分け
 _x = data_btc[n-M: n] # 入力変数
 _t = _t_btc[n] # 出力変数
 # 計算用のリスト(x, t)に追加していく
 x_btc.append(_x)
 t_btc.append(_t)

# %%
# numpyに変換
# x.shape : 1050,30 t.shape : 1050,1
x_btc = np.array(x_btc)
t_btc = np.array(t_btc)
x_btc = x_btc.reshape(x_btc.shape[0], x_btc.shape[1], 1)
N_train = int(len(x_btc) * 0.9)
x_train, x_test = x_btc[:N_train], x_btc[N_train:]
t_train, t_test = t_btc[:N_train], t_btc[N_train:]

# %%
mss = MinMaxScaler()
data_btc = pd.DataFrame(mss.fit_transform(data_btc))
data_btc = data_btc[0].astype(np.float32)
data_eth = pd.DataFrame(mss.fit_transform(data_eth))
data_eth = data_eth[0].astype(np.float32)

# %%
# データを入力変数xと出力変数tに切り分け
x_btc, t_btc = [], []
x_eth, t_eth = [], []
N = len(data_btc)
M = 30 # 入力変数の数：直近30サンプルを使用
for n in range(M, N):
 # 入力変数と出力変数の切り分け
 _x = data_btc[n-M: n] # 入力変数
 _t = data_btc[n] # 出力変数
 # 計算用のリスト(x, t)に追加していく
 x_btc.append(_x)
 t_btc.append(_t)
    
 _x = data_eth[n-M: n] # 入力変数
 _t = data_eth[n] # 出力変数
 # 計算用のリスト(x, t)に追加していく
 x_eth.append(_x)
 t_eth.append(_t)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:14031)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13975)()
#
# KeyError: 30
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-53b543fbbf44> in <module>()
#      13
#      14  _x = data_eth[n-M: n] # 入力変数
# ---> 15  _t = data_eth[n] # 出力変数
#      16  # 計算用のリスト(x, t)に追加していく
#      17  x_eth.append(_x)
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/.pyenv/versions/3.5.3/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:14031)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13975)()
#
# KeyError: 30

# %%
# numpyに変換
# x.shape : 1050,30 t.shape : 1050,1
x_btc = np.array(x_btc)
x_btc = x_btc.reshape(x_btc.shape[0], x_btc.shape[1], 1)
t_btc = np.array(t_btc).reshape(len(t_btc), 1) 
x_eth = np.array(x_eth)
x_eth = x_eth.reshape(x_eth.shape[0], x_eth.shape[1], 1)
t_eth = np.array(t_eth).reshape(len(t_eth), 1) 

# test, train分ける
N_train = int(len(x_btc) * 0.9)
x_train, x_test = np.append(x_btc[:N_train],x_eth[:N_train] , axis=0), x_btc[N_train:]
t_train, t_test = np.append(t_btc[:N_train],t_eth[:N_train], axis=0), t_btc[N_train:]
# Out:
# (1890, 30, 1)

# %% [markdown]
# - TODO keras LSTMの2つのdropoutの意味

# %%
# model
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

length_of_sequence = x_btc.shape[1] # 30 = M

in_out_neurons = 1
# n_hidden: 出力次元
n_hidden = 300
model = Sequential()
# return_sequenceとは、TrueにしてRNNレイヤーの毎時刻の出力を得るか、Falseにして最後の時刻のみの出力を得るか、のフラグ
# batch_iuput_shape: ([バッチサイズ，step数，特徴の次元数])
model.add(LSTM(units=n_hidden,
               batch_input_shape=(None, length_of_sequence, in_out_neurons), 
               return_sequences=False
              ))
model.add(Dropout(0.5))
model.add(Dense(in_out_neurons))
model.add(Activation("linear"))
optimizer = Adam(lr=0.001)
model.compile(loss="mean_squared_error", optimizer=optimizer)

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 300)               362400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 301
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 362,701
# Trainable params: 362,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model
# 4分類
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping

length_of_sequence = x_btc.shape[1] # 30 = M
n_in = x_btc.shape[2]   # 学習データ（＝入力）の列数
n_out = t_btc.shape[1]  # ラベルデータ（=出力）の列数

in_out_neurons = 1
# n_hidden: 出力次元
n_hidden = 300
model = Sequential()
# return_sequenceとは、TrueにしてRNNレイヤーの毎時刻の出力を得るか、Falseにして最後の時刻のみの出力を得るか、のフラグ
# batch_iuput_shape: ([バッチサイズ，step数，特徴の次元数])
model.add(LSTM(units=n_hidden,
               batch_input_shape=(None, length_of_sequence, n_in), 
               return_sequences=False
              ))
model.add(Dropout(0.5))
model.add(Dense(n_out))
model.add(Activation("softmax"))
optimizer = Adam(lr=0.001)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics = ['categorical_accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 300)               362400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 1204
# _________________________________________________________________
# activation_4 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 363,604
# Trainable params: 363,604
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_btc.shape
# Out:
# (1050, 30, 1)

# %% [markdown]
# ## 学習

# %%
early_stopping = EarlyStopping(monitor='val_loss', mode='auto', patience=20)
model.fit(x_train, t_train,
          batch_size=20,
          epochs=30,
          validation_split=0.1,
          shuffle=True,
          callbacks=[early_stopping]
          )
# Out:
# Train on 850 samples, validate on 95 samples
# Epoch 1/30
# 850/850 [==============================] - 6s - loss: 0.6907 - categorical_accuracy: 0.6765 - val_loss: 0.7651 - val_categorical_accuracy: 0.5579
# Epoch 2/30
# 850/850 [==============================] - 4s - loss: 0.6523 - categorical_accuracy: 0.6918 - val_loss: 0.7597 - val_categorical_accuracy: 0.5579
# Epoch 3/30
# 850/850 [==============================] - 4s - loss: 0.6392 - categorical_accuracy: 0.7024 - val_loss: 0.8076 - val_categorical_accuracy: 0.5579
# Epoch 4/30
# 850/850 [==============================] - 5s - loss: 0.6152 - categorical_accuracy: 0.7071 - val_loss: 0.8903 - val_categorical_accuracy: 0.5579
# Epoch 5/30
# 850/850 [==============================] - 5s - loss: 0.6283 - categorical_accuracy: 0.7047 - val_loss: 0.7499 - val_categorical_accuracy: 0.5579
# Epoch 6/30
# 850/850 [==============================] - 5s - loss: 0.6158 - categorical_accuracy: 0.7082 - val_loss: 0.7375 - val_categorical_accuracy: 0.5579
# Epoch 7/30
# 850/850 [==============================] - 4s - loss: 0.6303 - categorical_accuracy: 0.6953 - val_loss: 0.7566 - val_categorical_accuracy: 0.5579
# Epoch 8/30
# 850/850 [==============================] - 4s - loss: 0.6144 - categorical_accuracy: 0.7082 - val_loss: 0.7385 - val_categorical_accuracy: 0.5579
# Epoch 9/30
# 850/850 [==============================] - 5s - loss: 0.6240 - categorical_accuracy: 0.7082 - val_loss: 0.7712 - val_categorical_accuracy: 0.5579
# Epoch 10/30
# 850/850 [==============================] - 5s - loss: 0.6214 - categorical_accuracy: 0.7094 - val_loss: 0.7265 - val_categorical_accuracy: 0.5579
# Epoch 11/30
# 850/850 [==============================] - 5s - loss: 0.6092 - categorical_accuracy: 0.7094 - val_loss: 0.7393 - val_categorical_accuracy: 0.5579
# Epoch 12/30
# 850/850 [==============================] - 5s - loss: 0.6070 - categorical_accuracy: 0.7094 - val_loss: 0.7416 - val_categorical_accuracy: 0.5579
# Epoch 13/30
# 850/850 [==============================] - 5s - loss: 0.6160 - categorical_accuracy: 0.7094 - val_loss: 0.7595 - val_categorical_accuracy: 0.5579
# Epoch 14/30
# 850/850 [==============================] - 5s - loss: 0.6079 - categorical_accuracy: 0.7094 - val_loss: 0.7276 - val_categorical_accuracy: 0.5579
# Epoch 15/30
# 850/850 [==============================] - 5s - loss: 0.6071 - categorical_accuracy: 0.7094 - val_loss: 0.7060 - val_categorical_accuracy: 0.5579
# Epoch 16/30
# 850/850 [==============================] - 5s - loss: 0.6179 - categorical_accuracy: 0.7094 - val_loss: 0.7347 - val_categorical_accuracy: 0.5579
# Epoch 17/30
# 850/850 [==============================] - 5s - loss: 0.6090 - categorical_accuracy: 0.7094 - val_loss: 0.7470 - val_categorical_accuracy: 0.5579
# Epoch 18/30
# 850/850 [==============================] - 5s - loss: 0.6081 - categorical_accuracy: 0.7094 - val_loss: 0.7557 - val_categorical_accuracy: 0.5579
# Epoch 19/30
# 850/850 [==============================] - 5s - loss: 0.6077 - categorical_accuracy: 0.7106 - val_loss: 0.8031 - val_categorical_accuracy: 0.5579
# Epoch 20/30
# 850/850 [==============================] - 5s - loss: 0.6111 - categorical_accuracy: 0.7094 - val_loss: 0.7122 - val_categorical_accuracy: 0.5579
# Epoch 21/30
# 850/850 [==============================] - 5s - loss: 0.6119 - categorical_accuracy: 0.7094 - val_loss: 0.7316 - val_categorical_accuracy: 0.5579
# Epoch 22/30
# 850/850 [==============================] - 5s - loss: 0.6060 - categorical_accuracy: 0.7094 - val_loss: 0.7417 - val_categorical_accuracy: 0.5579
# Epoch 23/30
# 850/850 [==============================] - 5s - loss: 0.6122 - categorical_accuracy: 0.7094 - val_loss: 0.7429 - val_categorical_accuracy: 0.5579
# Epoch 24/30
# 850/850 [==============================] - 5s - loss: 0.6066 - categorical_accuracy: 0.7094 - val_loss: 0.7242 - val_categorical_accuracy: 0.5579
# Epoch 25/30
# 850/850 [==============================] - 5s - loss: 0.6063 - categorical_accuracy: 0.7094 - val_loss: 0.7589 - val_categorical_accuracy: 0.5579
# Epoch 26/30
# 850/850 [==============================] - 5s - loss: 0.6047 - categorical_accuracy: 0.7094 - val_loss: 0.7405 - val_categorical_accuracy: 0.5579
# Epoch 27/30
# 850/850 [==============================] - 5s - loss: 0.6073 - categorical_accuracy: 0.7094 - val_loss: 0.7625 - val_categorical_accuracy: 0.5579
# Epoch 28/30
# 850/850 [==============================] - 5s - loss: 0.6058 - categorical_accuracy: 0.7094 - val_loss: 0.7654 - val_categorical_accuracy: 0.5579
# Epoch 29/30
# 850/850 [==============================] - 5s - loss: 0.6126 - categorical_accuracy: 0.7094 - val_loss: 0.7236 - val_categorical_accuracy: 0.5579
# Epoch 30/30
# 850/850 [==============================] - 5s - loss: 0.6092 - categorical_accuracy: 0.7094 - val_loss: 0.7512 - val_categorical_accuracy: 0.5579

# %% [markdown]
# ## Test

# %%
score = model.evaluate(x_test, t_test, batch_size=20, verbose = 1)
print("score:", score)
# Out:
# 920/945 [============================>.] - ETA: 0sscore: [0.61807588373542466, 0.69417989947808478]

# %% [markdown]
# ## Predict

# %%
predicted = model.predict(x_test)
plt.figure()
plt.plot(range(0, len(predicted)), predicted, color="r", label="predict_data")
plt.plot(range(0, len(t_test)), t_test, color="b", label="row_data")
plt.legend()
plt.show()

# %%
# 正答率、準正答率（騰落）集計
preds = model.predict(x_test)
correct = 0
semi_correct = 0
for i in range(len(preds)):
  pred = np.argmax(preds[i,:])
  tar = np.argmax(t_test[i,:])
  if pred == tar :
    # 純粋な正解率
    correct += 1
  else :
    # 上下は当たってるやつ
    if pred+tar == 1 or pred+tar == 5 : 
      semi_correct += 1

print("正答率:", 1.0 * correct / len(preds))
print("準正答率（騰落）:", 1.0 * (correct+semi_correct) / len(preds))
# Out:
# 正答率: 0.6476190476190476
# 準正答率（騰落）: 0.6476190476190476
